# %% [markdown]
# ## Building a Basic Data Pipeline to ETL (Extract, Transform, Load) Data from a CSV File into a SQL Database.

# %% [markdown]
# ### Project Overview
#
# #### In this project, I am building a simple data pipeline that:
#
# #### 1. Extracts data from a CSV file.
# #### 2. Transforms the data (e.g., clean or preprocess).
# #### 3. Loads the data into a MySQL database.

# %% [markdown]
# #### Prerequisite before running below cells:
#
# #### 1. We need to create a new database or we can use any existing MySQL database
# #### 2. Create table with schema according to the columns available in the Players CSV file
# #### 3. The above steps can be implemented by running the ipl_players_table.sql file which includes the required code

# %%
#Installing Required libraries

#pip install pandas sqlalchemy mysql-connector-python

# %%
#Importing required libraries
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text
from datetime import datetime
import json

# %%
#Configuration

# Load configuration from a file
with open('config.json', 'r') as file:
    config = json.load(file)

username = config['username']
password = config['password']
hostname = config['hostname']
port = config['port']
database = config['database']

csv_file = 'Data/IPLPlayers.csv'
database_url = 'mysql+mysqlconnector://'+username+':'+password+'@'+hostname+':'+str(port)+'/'+database

# %%
#For checking the database URL
#database_url

# %%
# Step 1: Extract
def extract_data(file_path):
    df = pd.read_csv(file_path)
    return df

# %%
# Step 2: Clean
def clean_data(df, temp):
    # Removing unwanted column
    column_to_remove = df.columns[temp]
    df = df.drop(columns=[column_to_remove])
    df.replace('', np.nan, inplace=True)
    # Remove rows with any NaN or null values
    df_cleaned = df.dropna()
    # Remove duplicate rows
    df_cleaned = df_cleaned.drop_duplicates()
    return df_cleaned

# %%
# Function to convert date format to SQL Date format
"""
def convert_date(date_str):
    input_format = '%d-%b-%y'
    output_format = '%Y-%m-%d'
    date_obj = datetime.strptime(date_str, input_format)
    return date_obj.strftime(output_format)
"""
def convert_date(date_str):
    input_format = '%d-%b-%y'
    output_format = '%Y-%m-%d'
    if isinstance(date_str, str):
        try:
            date_obj = datetime.strptime(date_str, input_format)
            return date_obj.strftime(output_format)
        except ValueError:
            # Handle the case where the date_str does not match the input_format
            return date_str
    return date_str  # Return the value unchanged if it's not a string

# %%
# Step 3: Transform
def transform_data(df):
    df['Batting_Hand'] = df['Batting_Hand'].str.replace("_"," ")
    df['DOB'] = df['DOB'].apply(convert_date)
    return df

# %%
# Step 4: Load
def load_data(df, db_url):
    engine = create_engine(db_url)
    df.to_sql('players', engine, if_exists='replace', index=False)
    print('\nData loaded into MySQL database successfully.')

# %%
# Main pipeline function
def main():
    df = extract_data(csv_file)
    print("Showing first 3 rows of the loaded data: \n")
    print(df.head(3))
    df = clean_data(df,7) #Column 7 is unnecessary
    print()
    print("Showing Data after removing column 6: \n")
    print(df.head(3))
    df = transform_data(df)
    print("\nShowing Data after Data transformation: \n")
    print(df.head(3))
    load_data(df, database_url)

if __name__ == "__main__":
    main()
# Out:
# Showing first 3 rows of the loaded data:
#
#    Player_Id  Player_Name        DOB Batting_Hand     Bowling_Skill  \
# 0          1   SC Ganguly   8-Jul-72    Left_Hand  Right-arm medium
# 1          2  BB McCullum  27-Sep-81   Right_Hand  Right-arm medium
# 2          3   RT Ponting  19-Dec-74   Right_Hand  Right-arm medium
#
#        Country  Is_Umpire  Unnamed: 7
# 0        India          0         NaN
# 1  New Zealand          0         NaN
# 2    Australia          0         NaN
#
# Showing Data after removing column 6:
#
#    Player_Id  Player_Name        DOB Batting_Hand     Bowling_Skill  \
# 0          1   SC Ganguly   8-Jul-72    Left_Hand  Right-arm medium
# 1          2  BB McCullum  27-Sep-81   Right_Hand  Right-arm medium
# 2          3   RT Ponting  19-Dec-74   Right_Hand  Right-arm medium
#
#        Country  Is_Umpire
# 0        India          0
# 1  New Zealand          0
# 2    Australia          0
#
# Showing Data after Data transformation:
#
#    Player_Id  Player_Name         DOB Batting_Hand     Bowling_Skill  \
# 0          1   SC Ganguly  1972-07-08    Left Hand  Right-arm medium
# 1          2  BB McCullum  1981-09-27   Right Hand  Right-arm medium
# 2          3   RT Ponting  1974-12-19   Right Hand  Right-arm medium
#
#        Country  Is_Umpire
# 0        India          0
# 1  New Zealand          0
# 2    Australia          0
#
# Data loaded into MySQL database successfully.

# %%
engine = create_engine(database_url)

# Use a text object to execute raw SQL
with engine.connect() as connection:
    # Define the raw SQL query using text()
    sql_query = text("SELECT * FROM players")
    
    # Execute the query
    result = connection.execute(sql_query)
    
    # Fetch the results
    for row in result:
        print(row)
# Out:
# (1, 'SC Ganguly', '1972-07-08', 'Left Hand', 'Right-arm medium', 'India', 0)
# (2, 'BB McCullum', '1981-09-27', 'Right Hand', 'Right-arm medium', 'New Zealand', 0)
# (3, 'RT Ponting', '1974-12-19', 'Right Hand', 'Right-arm medium', 'Australia', 0)
# (4, 'DJ Hussey', '1977-07-15', 'Right Hand', 'Right-arm offbreak', 'Australia', 0)
# (5, 'Mohammad Hafeez', '1980-10-17', 'Right Hand', 'Right-arm offbreak', 'Pakistan', 0)
# (6, 'R Dravid', '1973-01-11', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (7, 'W Jaffer', '1978-02-16', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (8, 'V Kohli', '1988-11-05', 'Right Hand', 'Right-arm medium', 'India', 0)
# (9, 'JH Kallis', '1975-10-16', 'Right Hand', 'Right-arm fast-medium', 'South Africa', 0)
# (10, 'CL White', '1983-08-18', 'Right Hand', 'Legbreak googly', 'Australia', 0)
# (11, 'MV Boucher', '1976-12-03', 'Right Hand', 'Right-arm medium', 'South Africa', 0)
# (12, 'B Akhil', '1977-10-07', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (13, 'AA Noffke', '1977-04-30', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (14, 'P Kumar', '1986-10-02', 'Right Hand', 'Right-arm medium', 'India', 0)
# (15, 'Z Khan', '1978-10-07', 'Right Hand', 'Left-arm fast-medium', 'India', 0)
# (16, 'SB Joshi', '1970-06-06', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (18, 'ML Hayden', '1971-10-29', 'Left Hand', 'Right-arm medium', 'Australia', 0)
# (19, 'MEK Hussey', '1975-05-27', 'Left Hand', 'Right-arm medium', 'Australia', 0)
# (20, 'MS Dhoni', '1981-07-07', 'Right Hand', 'Right-arm medium', 'India', 0)
# (21, 'SK Raina', '1986-11-27', 'Left Hand', 'Right-arm offbreak', 'India', 0)
# (22, 'JDP Oram', '1978-07-28', 'Left Hand', 'Right-arm fast-medium', 'New Zealand', 0)
# (23, 'S Badrinath', '1980-08-30', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (24, 'K Goel', '1986-12-24', 'Left Hand', 'Right-arm offbreak', 'India', 0)
# (25, 'JR Hopes', '1978-10-24', 'Right Hand', 'Right-arm medium', 'Australia', 0)
# (26, 'KC Sangakkara', '1977-10-27', 'Left Hand', 'Right-arm offbreak', 'Sri Lanka', 0)
# (27, 'Yuvraj Singh', '1981-12-12', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (28, 'SM Katich', '1975-08-21', 'Left Hand', 'Slow left-arm chinaman', 'Australia', 0)
# (29, 'IK Pathan', '1984-10-27', 'Left Hand', 'Left-arm medium-fast', 'India', 0)
# (30, 'T Kohli', '1988-12-17', 'Right Hand', 'Right-arm medium', 'India', 0)
# (31, 'YK Pathan', '1982-11-17', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (32, 'SR Watson', '1981-06-17', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (33, 'M Kaif', '1980-12-01', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (34, 'DS Lehmann', '1970-02-05', 'Left Hand', 'Slow left-arm orthodox', 'Australia', 0)
# (35, 'RA Jadeja', '1988-12-06', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (37, 'D Salunkhe', '1982-11-12', 'Right Hand', 'Legbreak', 'India', 0)
# (38, 'SK Warne', '1969-09-13', 'Right Hand', 'Legbreak googly', 'Australia', 0)
# (39, 'SK Trivedi', '1982-09-04', 'Right Hand', 'Right-arm medium', 'India', 0)
# (40, 'G Gambhir', '1981-10-14', 'Left Hand', 'Legbreak', 'India', 0)
# (41, 'V Sehwag', '1978-10-20', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (42, 'S Dhawan', '1985-12-05', 'Left Hand', 'Right-arm offbreak', 'India', 0)
# (44, 'ST Jayasuriya', '1969-06-30', 'Left Hand', 'Slow left-arm orthodox', 'Sri Lanka', 0)
# (45, 'DJ Thornely', '1978-10-01', 'Right Hand', 'Right-arm medium', 'Australia', 0)
# (46, 'RV Uthappa', '1985-11-11', 'Right Hand', 'Right-arm medium', 'India', 0)
# (48, 'AM Nayar', '1983-10-08', 'Left Hand', 'Right-arm medium', 'India', 0)
# (49, 'SM Pollock', '1973-07-16', 'Right Hand', 'Right-arm fast-medium', 'South Africa', 0)
# (50, 'Harbhajan Singh', '1980-07-03', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (51, 'S Chanderpaul', '1974-08-16', 'Left Hand', 'Legbreak', 'West Indies', 0)
# (52, 'LRPL Taylor', '1984-03-08', 'Right Hand', 'Right-arm offbreak', 'New Zealand', 0)
# (53, 'AC Gilchrist', '1971-11-14', 'Left Hand', 'Right-arm offbreak', 'Australia', 0)
# (54, 'Y Venugopal Rao', '1982-02-26', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (55, 'VVS Laxman', '1974-11-01', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (56, 'A Symonds', '1975-06-09', 'Right Hand', 'Right-arm offbreak', 'Australia', 0)
# (57, 'RG Sharma', '1987-04-30', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (58, 'SB Styris', '1975-07-10', 'Right Hand', 'Right-arm medium', 'New Zealand', 0)
# (59, 'SB Bangar', '1972-10-11', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (60, 'WPUJC Vaas', '1974-01-27', 'Left Hand', 'Left-arm fast-medium', 'Sri Lanka', 0)
# (61, 'RP Singh', '1985-12-06', 'Right Hand', 'Left-arm fast-medium', 'India', 0)
# (63, 'LR Shukla', '1981-05-06', 'Right Hand', 'Right-arm medium', 'India', 0)
# (64, 'DPMD Jayawardene', '1977-05-27', 'Right Hand', 'Right-arm medium', 'Sri Lanka', 0)
# (65, 'S Sohal', '1987-11-10', 'Right Hand', 'Legbreak', 'India', 0)
# (66, 'B Lee', '1976-11-08', 'Right Hand', 'Right-arm fast', 'Australia', 0)
# (67, 'PP Chawla', '1988-12-24', 'Left Hand', 'Legbreak', 'India', 0)
# (68, 'WA Mota', '1981-09-20', 'Right Hand', 'Right-arm medium', 'India', 0)
# (70, 'Shahid Afridi', '1980-03-01', 'Right Hand', 'Legbreak googly', 'Pakistan', 0)
# (71, 'DJ Bravo', '1983-10-07', 'Right Hand', 'Right-arm medium-fast', 'West Indies', 0)
# (72, 'MA Khote', '1980-04-22', 'Right Hand', 'Right-arm medium', 'India', 0)
# (73, 'A Nehra', '1979-04-29', 'Right Hand', 'Left-arm medium-fast', 'India', 0)
# (74, 'GC Smith', '1981-02-01', 'Left Hand', 'Right-arm offbreak', 'South Africa', 0)
# (75, 'Pankaj Singh', '1985-05-06', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (76, 'RR Sarwan', '1980-06-23', 'Right Hand', 'Legbreak', 'West Indies', 0)
# (77, 'S Sreesanth', '1983-02-06', 'Right Hand', 'Right-arm fast-medium', 'India', 0)
# (78, 'VRV Singh', '1984-09-17', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (80, 'DS Kulkarni', '1988-12-10', 'Right Hand', 'Right-arm medium', 'India', 0)
# (81, 'R Vinay Kumar', '1984-02-12', 'Right Hand', 'Right-arm medium', 'India', 0)
# (82, 'AB Agarkar', '1977-12-04', 'Right Hand', 'Right-arm fast', 'India', 0)
# (83, 'M Kartik', '1976-09-11', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (84, 'I Sharma', '1988-09-02', 'Right Hand', 'Right-arm fast-medium', 'India', 0)
# (85, 'AM Rahane', '1988-06-06', 'Right Hand', 'Right-arm medium', 'India', 0)
# (86, 'Shoaib Malik', '1982-02-01', 'Right Hand', 'Right-arm offbreak', 'Pakistan', 0)
# (87, 'MK Tiwary', '1985-11-14', 'Right Hand', 'Legbreak googly', 'India', 0)
# (89, 'R Bhatia', '1979-10-22', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (90, 'MF Maharoof', '1984-09-07', 'Right Hand', 'Right-arm fast-medium', 'India', 0)
# (91, 'VY Mahesh', '1987-12-21', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (92, 'TM Srivastava', '1989-11-07', 'Left Hand', 'Right-arm medium', 'India', 0)
# (93, 'B Chipli', '1983-01-27', 'Right Hand', 'Right-arm medium', 'India', 0)
# (94, 'DW Steyn', '1983-06-27', 'Right Hand', 'Right-arm fast', 'South Africa', 0)
# (95, 'DB Das', '1986-09-22', 'Right Hand', 'Legbreak googly', 'India', 0)
# (96, 'MK Pandey', '1989-09-10', 'Right Hand', 'Right-arm medium', 'India', 0)
# (97, 'HH Gibbs', '1974-02-23', 'Right Hand', 'Right-arm bowler', 'South Africa', 0)
# (98, 'DNT Zoysa', '1978-05-13', 'Left Hand', 'Left-arm fast-medium', 'Sri Lanka', 0)
# (99, 'D Kalyankrishna', '1983-12-16', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (100, 'SE Marsh', '1983-07-09', 'Left Hand', 'Slow left-arm orthodox', 'Australia', 0)
# (101, 'SA Asnodkar', '1984-03-29', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (102, 'Sohail Tanvir', '1984-12-12', 'Left Hand', 'Left-arm medium-fast', 'Pakistan', 0)
# (103, 'Salman Butt', '1984-10-07', 'Left Hand', 'Right-arm offbreak', 'Pakistan', 0)
# (104, 'BJ Hodge', '1974-12-29', 'Right Hand', 'Right-arm offbreak', 'Australia', 0)
# (105, 'Umar Gul', '1984-04-14', 'Right Hand', 'Right-arm fast-medium', 'Pakistan', 0)
# (106, 'AB Dinda', '1984-03-25', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (108, 'S Vidyut', '1981-12-03', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (109, 'JA Morkel', '1981-06-10', 'Left Hand', 'Right-arm medium-fast', 'South Africa', 0)
# (110, 'AB de Villiers', '1984-02-17', 'Right Hand', 'Right-arm medium', 'South Africa', 0)
# (111, 'LPC Silva', '1979-12-14', 'Right Hand', 'Legbreak', 'Sri Lanka', 0)
# (112, 'DB Ravi Teja', '1987-09-05', 'Right Hand', 'Legbreak googly', 'India', 0)
# (113, 'Misbah-ul-Haq', '1974-05-28', 'Right Hand', 'Legbreak', 'Pakistan', 0)
# (115, 'RR Raje', '1986-09-03', 'Right Hand', 'Right-arm fast-medium', 'India', 0)
# (116, 'PJ Sangwan', '1990-11-05', 'Right Hand', 'Left-arm medium', 'India', 0)
# (117, 'Mohammad Asif', '1982-12-20', 'Left Hand', 'Right-arm fast-medium', 'Pakistan', 0)
# (118, 'GD McGrath', '1970-02-09', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (119, 'Joginder Sharma', '1983-10-23', 'Right Hand', 'Right-arm fast-medium', 'India', 0)
# (120, 'MS Gony', '1984-01-04', 'Right Hand', 'Right-arm medium', 'India', 0)
# (121, 'M Muralitharan', '1972-04-17', 'Right Hand', 'Right-arm offbreak', 'Sri Lanka', 0)
# (122, 'M Ntini', '1977-07-06', 'Right Hand', 'Right-arm fast', 'South Africa', 0)
# (124, 'A Kumble', '1970-10-17', 'Right Hand', 'Legbreak googly', 'India', 0)
# (126, 'MM Patel', '1983-07-12', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (127, 'CK Kapugedera', '1987-02-24', 'Right Hand', 'Right-arm medium', 'Sri Lanka', 0)
# (128, 'A Chopra', '1977-09-19', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (129, 'T Taibu', '1983-05-14', 'Right Hand', 'Right-arm medium', 'Zimbabwea', 0)
# (130, 'J Arunkumar', '1975-01-18', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (131, 'PP Ojha', '1986-09-05', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (133, 'SR Tendulkar', '1973-04-24', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (135, 'TM Dilshan', '1976-10-14', 'Right Hand', 'Right-arm offbreak', 'Sri Lanka', 0)
# (136, 'A Mishra', '1982-11-24', 'Right Hand', 'Legbreak', 'India', 0)
# (137, 'AD Mascarenhas', '1977-10-30', 'Right Hand', 'Right-arm fast-medium', 'England', 0)
# (139, 'LA Pomersbach', '1984-09-28', 'Left Hand', 'Right-arm offbreak', 'Australia', 0)
# (140, 'Iqbal Abdulla', '1989-12-02', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (141, 'Younis Khan', '1977-11-29', 'Right Hand', 'Right-arm medium', 'Pakistan', 0)
# (142, 'PM Sarvesh Kumar', '1989-04-26', 'Right Hand', 'Right-arm medium', 'India', 0)
# (143, 'DP Vijaykumar', '1986-10-20', 'Right Hand', 'Right-arm medium', 'India', 0)
# (144, 'Shoaib Akhtar', '1975-08-13', 'Right Hand', 'Right-arm fast', 'Pakistan', 0)
# (145, 'Abdur Razzak', '1982-06-15', 'Left Hand', 'Slow left-arm orthodox', 'Bangladesh', 0)
# (147, 'DR Smith', '1983-04-12', 'Right Hand', 'Right-arm medium', 'West Indies', 0)
# (148, 'SD Chitnis', '1987-05-06', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (149, 'CRD Fernando', '1979-07-19', 'Right Hand', 'Right-arm fast-medium', 'Sri Lanka', 0)
# (150, 'VS Yeligati', '1985-04-23', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (151, 'L Balaji', '1981-09-27', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (152, 'A Mukund', '1990-01-06', 'Left Hand', 'Legbreak googly', 'India', 0)
# (153, 'RR Powar', '1978-05-20', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (154, 'JP Duminy', '1984-04-14', 'Left Hand', 'Right-arm offbreak', 'South Africa', 0)
# (155, 'A Flintoff', '1977-12-06', 'Right Hand', 'Right-arm fast-medium', 'England', 0)
# (156, 'T Thushara', '1981-03-01', 'Left Hand', 'Left-arm fast-medium', 'Sri Lanka', 0)
# (157, 'JD Ryder', '1984-08-06', 'Left Hand', 'Right-arm medium', 'New Zealand', 0)
# (158, 'KP Pietersen', '1980-06-27', 'Right Hand', 'Right-arm offbreak', 'South Africa', 0)
# (159, 'T Henderson', '1974-08-01', 'Right Hand', 'Right-arm fast-medium', 'South Africa', 0)
# (160, 'Kamran Khan', '1991-03-10', 'Left Hand', 'Left-arm medium-fast', 'India', 0)
# (161, 'RS Bopara', '1985-05-04', 'Right Hand', 'Right-arm medium', 'England', 0)
# (162, 'CH Gayle', '1979-09-21', 'Left Hand', 'Right-arm offbreak', 'West Indies', 0)
# (163, 'MC Henriques', '1987-02-01', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (164, 'R Bishnoi', '1987-10-08', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (165, 'FH Edwards', '1982-02-06', 'Right Hand', 'Right-arm fast', 'West Indies', 0)
# (166, 'KV Sharma', '1987-10-23', 'Left Hand', 'Legbreak googly', 'India', 0)
# (167, 'PC Valthaty', '1983-12-07', 'Right Hand', 'Right-arm medium', 'India', 0)
# (168, 'RJ Quiney', '1982-08-20', 'Left Hand', 'Right-arm medium', 'Australia', 0)
# (169, 'AS Raut', '1987-03-03', 'Right Hand', 'Legbreak googly', 'India', 0)
# (170, 'Yashpal Singh', '1981-11-27', 'Right Hand', 'Right-arm medium', 'India', 0)
# (171, 'M Manhas', '1979-10-12', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (172, 'AA Bilakhia', '1986-05-31', 'Right Hand', 'Right-arm medium', 'India', 0)
# (173, 'AN Ghosh', '1986-10-19', 'Right Hand', 'Right-arm medium', 'India', 0)
# (174, 'BAW Mendis', '1985-03-11', 'Right Hand', 'Right-arm offbreak', 'Sri Lanka', 0)
# (175, 'DL Vettori', '1979-01-27', 'Left Hand', 'Slow left-arm orthodox', 'New Zealand', 0)
# (176, 'MN van Wyk', '1979-03-20', 'Right Hand', 'Slow left-arm orthodox', 'South Africa', 0)
# (177, 'RE van der Merwe', '1984-12-31', 'Right Hand', 'Slow left-arm orthodox', 'South Africa', 0)
# (178, 'TL Suman', '1983-12-15', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (179, 'Shoaib Ahmed', '1990-08-17', 'Right Hand', 'Right-arm fast-medium', 'Pakistan', 0)
# (180, 'GR Napier', '1980-01-06', 'Right Hand', 'Right-arm medium', 'England', 0)
# (181, 'KP Appanna', '1988-12-20', 'Right Hand', 'Slow left-arm orthodox', 'India', 0)
# (182, 'LA Carseldine', '1975-11-17', 'Left Hand', 'Left-arm medium', 'Australia', 0)
# (184, 'SM Harwood', '1974-03-01', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (185, 'M Vijay', '1984-04-01', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (186, 'SB Jakati', '1980-11-27', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (187, 'DA Warner', '1986-10-27', 'Left Hand', 'Legbreak', 'Australia', 0)
# (188, 'RJ Harris', '1979-10-11', 'Right Hand', 'Right-arm fast', 'Australia', 0)
# (189, 'D du Preez', '1981-11-08', 'Right Hand', 'Right-arm fast-medium', 'South Africa', 0)
# (190, 'M Morkel', '1984-10-06', 'Left Hand', 'Right-arm fast', 'South Africa', 0)
# (191, 'AD Mathews', '1987-06-02', 'Right Hand', 'Right-arm fast-medium', 'Sri Lanka', 0)
# (192, 'J Botha', '1982-05-02', 'Right Hand', 'Right-arm offbreak', 'South Africa', 0)
# (193, 'C Nanda', '1979-03-29', 'Right Hand', 'Legbreak', 'India', 0)
# (194, 'SL Malinga', '1983-08-28', 'Right Hand', 'Right-arm fast', 'Sri Lanka', 0)
# (195, 'Mashrafe Mortaza', '1983-10-05', 'Right Hand', 'Right-arm fast-medium', 'Bangladesh', 0)
# (196, 'A Singh', '1981-06-21', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (197, 'GJ Bailey', '1982-09-07', 'Right Hand', 'Right-arm medium', 'Australia', 0)
# (198, 'AB McDonald', '1981-06-05', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (199, 'Y Nagar', '1990-01-06', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (200, 'SS Shaikh', '1987-01-18', 'Right Hand', 'Right-arm medium', 'India', 0)
# (201, 'R Ashwin', '1986-09-17', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (202, 'Mohammad Ashraful', '1984-07-07', 'Right Hand', 'Right-arm offbreak', 'Bangladesh', 0)
# (203, 'CA Pujara', '1988-01-25', 'Right Hand', 'Legbreak', 'India', 0)
# (204, 'OA Shah', '1978-10-22', 'Right Hand', 'Right-arm offbreak', 'England', 0)
# (205, 'Anirudh Singh', '1980-08-02', 'Left Hand', 'Right-arm medium', 'India', 0)
# (206, 'Jaskaran Singh', '1989-09-04', 'Right Hand', 'Right-arm medium', 'India', 0)
# (208, 'AT Rayudu', '1985-09-23', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (209, 'R Sathish', '1981-01-14', 'Right Hand', 'Right-arm medium', 'India', 0)
# (210, 'R McLaren', '1983-02-09', 'Left Hand', 'Right-arm medium-fast', 'South Africa', 0)
# (211, 'AA Jhunjhunwala', '1982-12-01', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (212, 'P Dogra', '1984-11-19', 'Right Hand', 'Legbreak', 'India', 0)
# (213, 'A Uniyal', '1981-11-21', 'Left Hand', 'Left-arm medium', 'India', 0)
# (215, 'YA Abdulla', '1983-01-17', 'Left Hand', 'Left-arm fast-medium', 'India', 0)
# (216, 'EJG Morgan', '1986-09-10', 'Left Hand', 'Right-arm medium', 'England', 0)
# (217, 'JM Kemp', '1977-10-02', 'Right Hand', 'Right-arm fast-medium', 'South Africa', 0)
# (218, 'S Tyagi', '1987-09-17', 'Right Hand', 'Right-arm medium', 'India', 0)
# (219, 'RS Gavaskar', '1976-02-20', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (220, 'SE Bond', '1975-06-07', 'Right Hand', 'Right-arm fast', 'New Zealand', 0)
# (221, 'KA Pollard', '1987-05-12', 'Right Hand', 'Right-arm medium-fast', 'West Indies', 0)
# (222, 'S Ladda', '1986-07-10', 'Right Hand', 'Legbreak', 'India', 0)
# (223, 'DP Nannes', '1976-05-16', 'Right Hand', 'Left-arm fast', 'Australia', 0)
# (224, 'MJ Lumb', '1980-02-12', 'Left Hand', 'Right-arm medium', 'England', 0)
# (225, 'DR Martyn', '1971-10-21', 'Right Hand', 'Right-arm medium', 'Australia', 0)
# (226, 'S Narwal', '1982-04-16', 'Left Hand', 'Right-arm medium', 'India', 0)
# (227, 'AB Barath', '1990-04-14', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (228, 'Bipul Sharma', '1983-09-28', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (229, 'FY Fazal', '1985-09-07', 'Left Hand', 'Right-arm medium', 'India', 0)
# (230, 'AC Voges', '1979-10-04', 'Right Hand', 'Slow left-arm orthodox', 'Australia', 0)
# (231, 'MD Mishra', '1984-02-09', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (232, 'UT Yadav', '1987-10-25', 'Right Hand', 'Right-arm fast-medium', 'India', 0)
# (233, 'J Theron', '1985-07-24', 'Right Hand', 'Right-arm medium-fast', 'South Africa', 0)
# (234, 'SJ Srivastava', '1981-09-22', 'Right Hand', 'Left-arm fast-medium', 'India', 0)
# (235, 'R Sharma', '1987-04-30', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (236, 'Mandeep Singh', '1991-12-18', 'Right Hand', 'Right-arm medium', 'India', 0)
# (237, 'KM Jadhav', '1985-03-26', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (238, 'SW Tait', '1983-02-22', 'Right Hand', 'Right-arm fast', 'Australia', 0)
# (239, 'KB Arun Karthik', '1986-02-15', 'Right Hand', 'Legbreak googly', 'India', 0)
# (240, 'KAJ Roach', '1988-06-30', 'Right Hand', 'Right-arm fast', 'West Indies', 0)
# (241, 'PD Collingwood', '1976-05-26', 'Right Hand', 'Right-arm medium', 'England', 0)
# (242, 'CK Langeveldt', '1974-12-17', 'Right Hand', 'Right-arm fast-medium', 'England', 0)
# (243, 'VS Malik', '1983-05-09', 'Right Hand', 'Right-arm medium', 'India', 0)
# (244, 'A Mithun', '1989-10-25', 'Right Hand', 'Right-arm medium', 'India', 0)
# (245, 'AP Dole', '1987-10-09', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (246, 'AN Ahmed', '1988-11-05', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (247, 'RS Sodhi', '1980-10-18', 'Right Hand', 'Right-arm medium', 'India', 0)
# (248, 'DE Bollinger', '1981-07-24', 'Left Hand', 'Left-arm fast-medium', 'Australia', 0)
# (249, 'S Sriram', '1976-02-21', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (250, 'B Sumanth', '1988-05-10', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (253, 'MR Marsh', '1991-10-20', 'Right Hand', 'Right-arm medium', 'Australia', 0)
# (254, 'AJ Finch', '1986-11-17', 'Right Hand', 'Slow left-arm orthodox', 'Australia', 0)
# (255, 'STR Binny', '1984-06-03', 'Right Hand', 'Right-arm medium', 'India', 0)
# (256, 'Harmeet Singh', '1992-09-07', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (257, 'IR Jaggi', '1989-01-27', 'Right Hand', 'Legbreak googly', 'India', 0)
# (258, 'DT Christian', '1983-05-04', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (259, 'RV Gomez', '1985-10-16', 'Right Hand', 'Right-arm medium', 'India', 0)
# (261, 'AUK Pathan', '1984-06-17', 'Right Hand', 'Right-arm medium', 'India', 0)
# (262, 'UBT Chand', '1993-03-26', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (263, 'DJ Jacobs', '1982-11-04', 'Right Hand', 'Right-arm medium', 'South Africa', 0)
# (264, 'Sunny Singh', '1986-12-18', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (265, 'NJ Rimmington', '1982-11-11', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (266, 'AL Menaria', '1990-10-29', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (267, 'WD Parnell', '1989-07-30', 'Left Hand', 'Left-arm medium-fast', 'South Africa', 0)
# (268, 'JJ van der Wath', '1978-01-10', 'Right Hand', 'Right-arm medium-fast', 'South Africa', 0)
# (269, 'R Ninan', '1985-11-19', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (270, 'S Aravind', '1984-04-08', 'Left Hand', 'Left-arm medium-fast', 'India', 0)
# (271, 'MS Wade', '1987-12-26', 'Left Hand', 'Right-arm medium', 'Australia', 0)
# (272, 'TD Paine', '1984-12-08', 'Right Hand', 'Right-arm medium', 'Australia', 0)
# (273, 'SB Wagh', '1988-10-09', 'Left Hand', 'Left-arm medium-fast', 'India', 0)
# (274, 'AC Thomas', '1977-02-09', 'Right Hand', 'Right-arm fast-medium', 'England', 0)
# (275, 'JEC Franklin', '1980-11-07', 'Left Hand', 'Left-arm medium', 'New Zealand', 0)
# (276, 'Shakib Al Hasan', '1987-03-24', 'Left Hand', 'Slow left-arm orthodox', 'Bangladesh', 0)
# (278, 'S Randiv', '1985-01-30', 'Right Hand', 'Right-arm offbreak', 'Sri Lanka', 0)
# (280, 'NLTC Perera', '1989-04-03', 'Left Hand', 'Right-arm medium-fast', 'Sri Lanka', 0)
# (281, 'NL McCullum', '1980-09-01', 'Right Hand', 'Right-arm offbreak', 'New Zealand', 0)
# (282, 'JE Taylor', '1984-06-22', 'Right Hand', 'Right-arm fast', 'New Zealand', 0)
# (283, 'J Syed Mohammad', '1983-06-03', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (284, 'RN ten Doeschate', '1980-06-30', 'Right Hand', 'Right-arm medium-fast', 'Netherlands', 0)
# (285, 'TR Birt', '1981-12-09', 'Left Hand', 'Right-arm medium', 'Australia', 0)
# (286, 'AG Murtaza', '1990-01-01', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (287, 'Harpreet Singh', '1991-08-11', 'Left Hand', 'Right-arm medium', 'India', 0)
# (289, 'AC Blizzard', '1984-06-27', 'Left Hand', 'Left-arm medium', 'Australia', 0)
# (290, 'I Malhotra', '1984-05-23', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (291, 'L Ablish', '1982-12-03', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (292, 'CA Ingram', '1985-07-03', 'Left Hand', 'Legbreak', 'South Africa', 0)
# (293, 'S Nadeem', '1989-08-12', 'Right Hand', 'Slow left-arm orthodox', 'India', 0)
# (294, 'P Parameswaran', '1985-05-30', 'Right Hand', 'Left-arm medium', 'India', 0)
# (295, 'CJ Ferguson', '1984-11-21', 'Right Hand', 'Right-arm medium', 'Australia', 0)
# (296, 'VR Aaron', '1989-10-29', 'Right Hand', 'Right-arm fast', 'India', 0)
# (297, 'AA Chavan', '1985-10-28', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (298, 'ND Doshi', '1978-10-06', 'Right Hand', 'Slow left-arm orthodox', 'India', 0)
# (299, 'B Kumar', '1990-02-05', 'Right Hand', 'Right-arm medium', 'India', 0)
# (300, 'Y Gnaneswara Rao', '1984-08-25', 'Right Hand', 'Right-arm medium', 'India', 0)
# (301, 'S Rana', '1984-09-18', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (302, 'BA Bhatt', '1990-05-13', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (303, 'F du Plessis', '1984-07-13', 'Right Hand', 'Legbreak', 'South Africa', 0)
# (304, 'RE Levi', '1988-01-14', 'Right Hand', 'Right-arm medium', 'South Africa', 0)
# (305, 'GJ Maxwell', '1988-10-14', 'Right Hand', 'Right-arm offbreak', 'Australia', 0)
# (306, 'SPD Smith', '1989-06-02', 'Right Hand', 'Legbreak googly', 'India', 0)
# (307, 'MN Samuels', '1981-02-05', 'Right Hand', 'Right-arm offbreak', 'West Indies', 0)
# (308, 'SA Yadav', '1990-09-14', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (309, 'KK Cooper', '1989-02-16', 'Right Hand', 'Right-arm medium', 'West Indies', 0)
# (310, 'JP Faulkner', '1990-04-29', 'Right Hand', 'Left-arm fast-medium', 'Australia', 0)
# (311, 'HV Patel', '1990-11-23', 'Right Hand', 'Right-arm medium', 'India', 0)
# (312, 'DAJ Bracewell', '1990-09-28', 'Right Hand', 'Right-arm fast-medium', 'New Zealand', 0)
# (313, 'DJ Harris', '1979-12-31', 'Right Hand', 'Right-arm medium', 'Australia', 0)
# (314, 'Ankit Sharma', '1991-04-20', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (315, 'SP Narine', '1988-05-26', 'Left Hand', 'Right-arm offbreak', 'West Indies', 0)
# (316, 'GB Hogg', '1971-02-06', 'Left Hand', 'Slow left-arm chinaman', 'Australia', 0)
# (317, 'RR Bhatkal', '1985-09-01', 'Right Hand', 'Right-arm medium', 'India', 0)
# (318, 'CJ McKay', '1983-02-20', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (320, 'DA Miller', '1989-06-10', 'Left Hand', 'Right-arm offbreak', 'South Africa', 0)
# (321, 'Azhar Mahmood', '1975-02-28', 'Right Hand', 'Right-arm fast-medium', 'Pakistan', 0)
# (322, 'P Negi', '1993-01-06', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (323, 'RJ Peterson', '1979-08-04', 'Left Hand', 'Slow left-arm orthodox', 'South Africa', 0)
# (324, 'KMDN Kulasekara', '1982-07-22', 'Right Hand', 'Right-arm fast-medium', 'Sri Lanka', 0)
# (325, 'A Ashish Reddy', '1991-02-24', 'Right Hand', 'Right-arm medium', 'India', 0)
# (326, 'V Pratap Singh', '1992-05-03', 'Right Hand', 'Right-arm medium', 'India', 0)
# (328, 'MJ Clarke', '1981-04-02', 'Right Hand', 'Slow left-arm orthodox', 'Australia', 0)
# (329, 'Gurkeerat Singh', '1990-06-29', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (330, 'AP Majumdar', '1984-04-30', 'Right Hand', 'Legbreak googly', 'India', 0)
# (331, 'PA Reddy', '1991-02-11', 'Right Hand', 'Legbreak', 'India', 0)
# (332, 'K Upadhyay', '1986-06-18', 'Right Hand', 'Right-arm medium', 'India', 0)
# (333, 'P Awana', '1986-07-19', 'Right Hand', 'Right-arm medium', 'India', 0)
# (334, 'AD Russell', '1988-04-29', 'Right Hand', 'Right-arm fast', 'West Indies', 0)
# (335, 'A Chandila', '1983-12-05', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (336, 'CA Lynn', '1990-04-10', 'Right Hand', 'Slow left-arm orthodox', 'Australia', 0)
# (337, 'Sunny Gupta', '1988-09-27', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (338, 'MC Juneja', '1990-09-12', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (339, 'KK Nair', '1991-12-06', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (340, 'GH Vihari', '1993-10-13', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (342, 'R Shukla', '1990-08-28', 'Right Hand', 'Right-arm medium', 'India', 0)
# (343, 'B Laughlin', '1982-10-03', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (344, 'AS Rajpoot', '1993-12-04', 'Right Hand', 'Right-arm medium', 'India', 0)
# (345, 'M Vohra', '1993-07-18', 'Right Hand', 'Right-arm medium', 'India', 0)
# (346, 'JD Unadkat', '1991-10-18', 'Right Hand', 'Left-arm medium', 'India', 0)
# (347, 'Mohammed Shami', '1990-09-03', 'Right Hand', 'Right-arm fast-medium', 'India', 0)
# (348, 'BMAJ Mendis', '1983-01-15', 'Left Hand', 'Legbreak', 'Sri Lanka', 0)
# (349, 'R Rampaul', '1984-10-15', 'Left Hand', 'Right-arm fast-medium', 'West Indies', 0)
# (350, 'CH Morris', '1987-04-30', 'Right Hand', 'Right-arm fast-medium', 'South Africa', 0)
# (352, 'SMSM Senanayake', '1985-02-09', 'Right Hand', 'Right-arm offbreak', 'Sri Lanka', 0)
# (356, 'R Dhawan', '1990-02-19', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (357, 'MG Johnson', '1981-11-02', 'Left Hand', 'Left-arm fast', 'Australia', 0)
# (358, 'LJ Wright', '1985-03-07', 'Right Hand', 'Right-arm medium-fast', 'England', 0)
# (359, 'IC Pandey', '1989-08-15', 'Right Hand', 'Right-arm medium', 'India', 0)
# (361, 'X Thalaivan Sargunam', '1985-05-15', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (362, 'DJG Sammy', '1983-12-20', 'Right Hand', 'Right-arm medium-fast', 'West Indies', 0)
# (363, 'KW Richardson', '1991-02-12', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (364, 'MM Sharma', '1988-09-18', 'Right Hand', 'Right-arm medium', 'India', 0)
# (365, 'UA Birla', '1989-11-17', 'Right Hand', 'Right-arm medium', 'India', 0)
# (366, 'Parvez Rasool', '1989-02-13', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (367, 'Sandeep Sharma', '1993-05-18', 'Right Hand', 'Right-arm medium', 'India', 0)
# (368, 'S Kaul', '1990-05-19', 'Right Hand', 'Right-arm medium', 'India', 0)
# (369, 'Sachin Baby', '1988-12-18', 'Left Hand', 'Right-arm offbreak', 'India', 0)
# (370, 'PV Tambe', '1971-10-08', 'Right Hand', 'Legbreak', 'India', 0)
# (371, 'NM Coulter-Nile', '1987-10-11', 'Right Hand', 'Right-arm fast', 'Australia', 0)
# (372, 'CJ Anderson', '1990-12-13', 'Left Hand', 'Left-arm medium-fast', 'New Zealand', 0)
# (373, 'NJ Maddinson', '1991-12-21', 'Left Hand', 'Slow left-arm orthodox', 'Australia', 0)
# (374, 'AR Patel', '1994-01-20', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (375, 'JJ Bumrah', '1993-12-06', 'Right Hand', 'Right-arm medium', 'India', 0)
# (376, 'JDS Neesham', '1990-09-17', 'Left Hand', 'Right-arm medium', 'New Zealand', 0)
# (377, 'TG Southee', '1988-12-11', 'Right Hand', 'Right-arm medium-fast', 'New Zealand', 0)
# (378, 'MA Starc', '1990-01-30', 'Left Hand', 'Left-arm fast', 'Australia', 0)
# (380, 'RR Rossouw', '1989-10-09', 'Left Hand', 'Right-arm offbreak', 'South Africa', 0)
# (381, 'Shivam Sharma', '1993-09-09', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (382, 'YS Chahal', '1990-07-23', 'Right Hand', 'Legbreak googly', 'India', 0)
# (383, 'LMP Simmons', '1985-01-25', 'Right Hand', 'Right-arm medium-fast', 'West Indies', 0)
# (384, 'VH Zol', '1994-11-23', 'Left Hand', 'Right-arm offbreak', 'India', 0)
# (385, 'BCJ Cutting', '1987-01-30', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (386, 'Imran Tahir', '1979-03-27', 'Right Hand', 'Legbreak googly', 'India', 0)
# (387, 'BE Hendricks', '1990-06-08', 'Left Hand', 'Left-arm fast-medium', 'South Africa', 0)
# (388, 'S Gopal', '1993-09-04', 'Right Hand', 'Legbreak', 'India', 0)
# (389, 'M de Lange', '1990-10-13', 'Right Hand', 'Right-arm fast', 'South Africa', 0)
# (390, 'R Tewatia', '1993-05-20', 'Left Hand', 'Legbreak', 'India', 0)
# (391, 'JO Holder', '1991-11-05', 'Right Hand', 'Right-arm medium-fast', 'West Indies', 0)
# (392, 'Karanveer Singh', '1987-11-08', 'Right Hand', 'Legbreak googly', 'India', 0)
# (393, 'SS Iyer', '1994-12-06', 'Right Hand', 'Legbreak googly', 'India', 0)
# (394, 'DJ Hooda', '1995-04-19', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (395, 'Anureet Singh', '1988-03-02', 'Right Hand', 'Right-arm medium', 'India', 0)
# (396, 'KS Williamson', '1990-08-08', 'Right Hand', 'Right-arm offbreak', 'New Zealand', 0)
# (397, 'SA Abbott', '1992-02-29', 'Right Hand', 'Right-arm fast-medium', 'New Zealand', 0)
# (398, 'J Suchith', '1994-01-16', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (399, 'RG More', '1992-02-02', 'Right Hand', 'Right-arm medium', 'India', 0)
# (400, 'HH Pandya', '1993-10-11', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (401, 'D Wiese', '1985-05-18', 'Right Hand', 'Right-arm medium-fast', 'South Africa', 0)
# (402, 'SN Khan', '1997-10-27', 'Right Hand', 'Legbreak', 'India', 0)
# (403, 'MJ McClenaghan', '1986-06-11', 'Left Hand', 'Left-arm fast-medium', 'New Zealand', 0)
# (404, 'DJ Muthuswami', '1981-03-09', 'Right Hand', 'Right-arm medium', 'India', 0)
# (405, 'PJ Cummins', '1993-05-08', 'Right Hand', 'Right-arm fast', 'Australia', 0)
# (406, 'SN Thakur', '1991-10-16', 'Right Hand', 'Right-arm medium', 'India', 0)
# (408, 'CR Brathwaite', '1988-07-18', 'Right Hand', 'Right-arm fast-medium', 'West Indies', 0)
# (409, 'MP Stoinis', '1989-08-16', 'Right Hand', 'Right-arm medium', 'Australia', 0)
# (411, 'C Munro', '1987-03-11', 'Left Hand', 'Right-arm medium-fast', 'New Zealand', 0)
# (412, 'P Sahu', '1985-08-21', 'Right Hand', 'Legbreak googly', 'India', 0)
# (413, 'KH Pandya', '1991-03-24', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (414, 'AD Nath', '1993-05-10', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (415, 'MJ Guptill', '1986-09-30', 'Right Hand', 'Right-arm offbreak', 'New Zealand', 0)
# (416, 'KJ Abbott', '1987-06-18', 'Right Hand', 'Right-arm fast-medium', 'South Africa', 0)
# (417, 'TM Head', '1993-12-29', 'Left Hand', 'Right-arm offbreak', 'Australia', 0)
# (418, 'M Ashwin', '1990-09-08', 'Right Hand', 'Legbreak googly', 'India', 0)
# (422, 'KC Cariappa', '1994-04-13', 'Right Hand', 'Legbreak', 'India', 0)
# (424, 'Swapnil Singh', '1991-01-22', 'Right Hand', 'Slow left-arm orthodox', 'India', 0)
# (425, 'J Yadav', '1990-01-22', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (426, 'UT Khawaja', '1986-12-18', 'Left Hand', 'Right-arm medium', 'Australia', 0)
# (427, 'HM Amla', '1983-03-31', 'Right Hand', 'Right-arm offbreak', 'South Africa', 0)
# (428, 'F Behardien', '1983-10-09', 'Right Hand', 'Right-arm fast-medium', 'South Africa', 0)
# (429, 'BB Sran', '1992-12-10', 'Left Hand', 'Left-arm medium', 'India', 0)
# (430, 'A Zampa', '1992-03-31', 'Right Hand', 'Legbreak googly', 'Australia', 0)
# (431, 'N Rana', '1993-12-27', 'Left Hand', 'Right-arm offbreak', 'India', 0)
# (432, 'S Kaushik', '1995-09-07', 'Right Hand', 'Slow left-arm chinaman', 'India', 0)
# (434, 'CJ Jordan', '1988-10-04', 'Right Hand', 'Right-arm fast-medium', 'England', 0)
# (435, 'P Amarnath', '1982-06-01', 'Right Hand', 'Right-arm medium', 'India', 0)
# (436, 'B Geeves', '1982-06-13', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (437, 'Gagandeep Singh', '1981-10-03', 'Right Hand', 'Right-arm medium-fast', 'India', 0)
# (438, 'A Nel', '1977-07-15', 'Right Hand', 'Right-arm fast-medium', 'South Africa', 0)
# (439, 'AM Salvi', '1981-10-20', 'Right Hand', 'Right-arm medium', 'India', 0)
# (440, 'RR Bose', '1979-02-27', 'Right Hand', 'Right-arm fast-medium', 'India', 0)
# (441, 'SS Sarkar', '1984-12-15', 'Right Hand', 'Right-arm medium', 'India', 0)
# (442, 'RA Shaikh', '1985-06-12', 'Left Hand', 'Left-arm medium', 'India', 0)
# (443, 'C Ganapathy', '1981-06-10', 'Right Hand', 'Right-arm medium', 'India', 0)
# (444, 'MB Parmar', '1988-04-12', 'Right Hand', 'Right-arm offbreak', 'India', 0)
# (445, 'AA Kazi', '1989-09-29', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (446, 'Anand Rajan', '1987-04-17', 'Right Hand', 'Right-arm medium', 'India', 0)
# (447, 'P Prasanth', '1985-05-22', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (448, 'SS Mundhe', '1988-10-27', 'Right Hand', 'Right-arm medium', 'India', 0)
# (449, 'RW Price', '1976-06-12', 'Right Hand', 'Slow left-arm orthodox', 'Zimbabwea', 0)
# (450, 'TP Sudhindra', '1984-04-24', 'Left Hand', 'Right-arm fast', 'India', 0)
# (451, 'BW Hilfenhaus', '1983-03-15', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (452, 'S Badree', '1981-03-09', 'Right Hand', 'Legbreak', 'West Indies', 0)
# (453, 'P Suyal', '1989-10-15', 'Right Hand', 'Left-arm medium', 'India', 0)
# (454, 'MG Neser', '1990-03-29', 'Right Hand', 'Right-arm medium', 'Australia', 0)
# (455, 'V Shankar', '1991-01-26', 'Right Hand', 'Right-arm medium', 'India', 0)
# (456, 'K Santokie', '1984-12-20', 'Left Hand', 'Left-arm medium', 'West Indies', 0)
# (457, 'JW Hastings', '1985-11-04', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (458, 'TA Boult', '1989-07-22', 'Right Hand', 'Left-arm fast-medium', 'New Zealand', 0)
# (459, 'GS Sandhu', '1993-06-14', 'Left Hand', 'Right-arm fast-medium', 'Australia', 0)
# (460, 'Mustafizur Rahman', '1995-09-06', 'Left Hand', 'Left-arm fast-medium', 'Bangladesh', 0)
# (461, 'AF Milne', '1992-04-13', 'Right Hand', 'Right-arm fast', 'New Zealand', 0)
# (462, 'Kuldeep Yadav', '1994-12-14', 'Left Hand', 'Slow left-arm chinaman', 'India', 0)
# (463, 'T Shamsi', '1990-02-18', 'Right Hand', 'Slow left-arm chinaman', 'South Africa', 0)
# (464, 'SM Boland', '1989-04-11', 'Right Hand', 'Right-arm fast-medium', 'Australia', 0)
# (465, 'DL Chahar', '1992-08-07', 'Right Hand', 'Right-arm medium', 'India', 0)
# (467, 'RV Pawar', '1979-09-06', 'Left Hand', 'Slow left-arm orthodox', 'India', 0)
# (469, 'T Mishra', '1986-12-22', 'Right Hand', 'Right-arm fast-medium', 'India', 0)
# (524, 'B Aparajith', '1994-07-08', 'Right Hand', 'Right-arm offbreak', 'India', 0)
